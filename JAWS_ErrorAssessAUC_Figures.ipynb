# %% [markdown]
# ## Notebook for processing predictive values for AUC error assessment experiments and plotting AUC results in "JAWS" paper
#
# #### Prinster, A., Liu, A., & Saria, S. JAWS: Auditing Predictive Uncertainty Under Covariate Shift. In Advances in Neural Information Processing Systems.
#
# Last updated: January 4, 2023

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
np.random.seed(98765)

## Drew added
import tqdm as tqdm
import random

from JAWS_utils_20230103 import *

import os

# %% [markdown]
# ## Airfoil RF mu

# %%
'''Specify dataset and mu function (predictor) here'''

dataset = 'airfoil' ## dataset \in ['airfoil', 'wine', 'wave', 'superconduct', 'communities']
mu = 'RF'  ## mu \in ['RF', 'NN']
num_trials = 50

'''
If 1st run : Specify 'predictive_values_file_path' as output of '20220729_run_JAW_PredictiveValuesForAUC.py'
             for dataset and mu above
'''
predictive_values_file_path = './results/JAWE_error_assessment/2023-01-04_airfoil_RF_0.85Bias_50Trials_PVs.csv'
AUC_results_path = calculate_AUC(predictive_values_file_path, dataset, mu)
print("Saved AUC results at path : " + AUC_results_path)


'''
If not 1st run : 
    Comment 3 lines above (used for 1st run)
    Uncomment 1st line below and specify 'AUC_results_path' as output from 'calculate_AUC' function above
    Optionally : Uncomment 2nd line below to delete file located at 'predictive_values_file_path' for storage
'''
# AUC_results_path = ''
### if (os.path.exists(predictive_values_file_path)): os.remove(predictive_values_file_path)


'''Plot AUC results'''
plot_AUC(AUC_results_path, dataset, mu, num_trials)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [07:58<00:00,  9.56s/it]
# Saved AUC results at path : ./results/JAWE_error_assessment/2023-01-04_AUC_airfoil_RF_data.csv

# %% [markdown]
# ### Airfoil NN

# %%
'''Specify dataset and mu function (predictor) here'''

dataset = 'airfoil' ## dataset \in ['airfoil', 'wine', 'wave', 'superconduct', 'communities']
mu = 'NN'  ## mu \in ['RF', 'NN']
num_trials = 50

'''
If 1st run : Specify 'predictive_values_file_path' as output of '20220729_run_JAW_PredictiveValuesForAUC.py'
             for dataset and mu above
'''
predictive_values_file_path = './results/JAWE_error_assessment/2023-01-04_airfoil_NN_0.85Bias_50Trials_PVs.csv'
AUC_results_path = calculate_AUC(predictive_values_file_path, dataset, mu)
print("Saved AUC results at path : " + AUC_results_path)


'''
If not 1st run : 
    Comment 3 lines above (used for 1st run)
    Uncomment 1st line below and specify 'AUC_results_path' as output from 'calculate_AUC' function above
    Optionally : Uncomment 2nd line below to delete file located at 'predictive_values_file_path' for storage
'''
# AUC_results_path = './results/JAWE_error_assessment/2023-01-04_AUC_airfoil_NN_data.csv'
### if (os.path.exists(predictive_values_file_path)): os.remove(predictive_values_file_path)


'''Plot AUC results'''
plot_AUC(AUC_results_path, dataset, mu, num_trials)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [08:39<00:00, 10.39s/it]
# Saved AUC results at path : ./results/JAWE_error_assessment/2023-01-04_AUC_airfoil_NN_data.csv

# %% [markdown]
# ### Wine RF

# %%
'''Specify dataset and mu function (predictor) here'''

dataset = 'wine' ## dataset \in ['airfoil', 'wine', 'wave', 'superconduct', 'communities']
mu = 'RF'  ## mu \in ['RF', 'NN']
num_trials = 50

'''
If 1st run : Specify 'predictive_values_file_path' as output of '20220729_run_JAW_PredictiveValuesForAUC.py'
             for dataset and mu above
'''
predictive_values_file_path = './results/JAWE_error_assessment/2023-01-04_wine_RF_0.53Bias_50Trials_PVs.csv'
AUC_results_path = calculate_AUC(predictive_values_file_path, dataset, mu)
print("Saved AUC results at path : " + AUC_results_path)


'''
If not 1st run : 
    Comment 3 lines above (used for 1st run)
    Uncomment 1st line below and specify 'AUC_results_path' as output from 'calculate_AUC' function above
    Optionally : Uncomment 2nd line below to delete file located at 'predictive_values_file_path' for storage
'''
# AUC_results_path = ''
### if (os.path.exists(predictive_values_file_path)): os.remove(predictive_values_file_path)


'''Plot AUC results'''
plot_AUC(AUC_results_path, dataset, mu, num_trials)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [08:48<00:00, 10.58s/it]
# Saved AUC results at path : ./results/JAWE_error_assessment/2023-01-04_AUC_wine_RF_data.csv

# %% [markdown]
# ### Wine NN

# %%
'''Specify dataset and mu function (predictor) here'''

dataset = 'wine' ## dataset \in ['airfoil', 'wine', 'wave', 'superconduct', 'communities']
mu = 'NN'  ## mu \in ['RF', 'NN']
num_trials = 50

'''
If 1st run : Specify 'predictive_values_file_path' as output of '20220729_run_JAW_PredictiveValuesForAUC.py'
             for dataset and mu above
'''
predictive_values_file_path = './results/JAWE_error_assessment/2023-01-04_wine_NN_0.53Bias_50Trials_PVs.csv'
AUC_results_path = calculate_AUC(predictive_values_file_path, dataset, mu)
print("Saved AUC results at path : " + AUC_results_path)


'''
If not 1st run : 
    Comment 3 lines above (used for 1st run)
    Uncomment 1st line below and specify 'AUC_results_path' as output from 'calculate_AUC' function above
    Optionally : Uncomment 2nd line below to delete file located at 'predictive_values_file_path' for storage
'''
# AUC_results_path = ''
### if (os.path.exists(predictive_values_file_path)): os.remove(predictive_values_file_path)


'''Plot AUC results'''
plot_AUC(AUC_results_path, dataset, mu, num_trials)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [09:24<00:00, 11.29s/it]
# Saved AUC results at path : ./results/JAWE_error_assessment/2023-01-04_AUC_wine_NN_data.csv

# %% [markdown]
# ### Wave RF

# %%
'''Specify dataset and mu function (predictor) here'''

dataset = 'wave' ## dataset \in ['airfoil', 'wine', 'wave', 'superconduct', 'communities']
mu = 'RF'  ## mu \in ['RF', 'NN']
num_trials = 50

'''
If 1st run : Specify 'predictive_values_file_path' as output of '20220729_run_JAW_PredictiveValuesForAUC.py'
             for dataset and mu above
'''
predictive_values_file_path = './results/JAWE_error_assessment/2023-01-04_wave_RF_9.25e-05Bias_50Trials_PVs.csv'
AUC_results_path = calculate_AUC(predictive_values_file_path, dataset, mu)
print("Saved AUC results at path : " + AUC_results_path)


'''
If not 1st run : 
    Comment 3 lines above (used for 1st run)
    Uncomment 1st line below and specify 'AUC_results_path' as output from 'calculate_AUC' function above
    Optionally : Uncomment 2nd line below to delete file located at 'predictive_values_file_path' for storage
'''
# AUC_results_path = ''
### if (os.path.exists(predictive_values_file_path)): os.remove(predictive_values_file_path)


'''Plot AUC results'''
plot_AUC(AUC_results_path, dataset, mu, num_trials)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [11:56<00:00, 14.34s/it]
# Saved AUC results at path : ./results/JAWE_error_assessment/2023-01-04_AUC_wave_RF_data.csv

# %% [markdown]
# ### Wave NN

# %%
'''Specify dataset and mu function (predictor) here'''

dataset = 'wave' ## dataset \in ['airfoil', 'wine', 'wave', 'superconduct', 'communities']
mu = 'NN'  ## mu \in ['RF', 'NN']
num_trials = 50

'''
If 1st run : Specify 'predictive_values_file_path' as output of '20220729_run_JAW_PredictiveValuesForAUC.py'
             for dataset and mu above
'''
predictive_values_file_path = './results/JAWE_error_assessment/2023-01-04_wave_NN_9.25e-05Bias_50Trials_PVs.csv'
AUC_results_path = calculate_AUC(predictive_values_file_path, dataset, mu)
print("Saved AUC results at path : " + AUC_results_path)


'''
If not 1st run : 
    Comment 3 lines above (used for 1st run)
    Uncomment 1st line below and specify 'AUC_results_path' as output from 'calculate_AUC' function above
    Optionally : Uncomment 2nd line below to delete file located at 'predictive_values_file_path' for storage
'''
# AUC_results_path = ''
### if (os.path.exists(predictive_values_file_path)): os.remove(predictive_values_file_path)


'''Plot AUC results'''
plot_AUC(AUC_results_path, dataset, mu, num_trials)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [11:27<00:00, 13.74s/it]
# Saved AUC results at path : ./results/JAWE_error_assessment/2023-01-04_AUC_wave_NN_data.csv

# %% [markdown]
# ### Superconduct RF

# %%
'''Specify dataset and mu function (predictor) here'''

dataset = 'superconduct' ## dataset \in ['airfoil', 'wine', 'wave', 'superconduct', 'communities']
mu = 'RF'  ## mu \in ['RF', 'NN']
num_trials = 50

'''
If 1st run : Specify 'predictive_values_file_path' as output of '20220729_run_JAW_PredictiveValuesForAUC.py'
             for dataset and mu above
'''
predictive_values_file_path = './results/JAWE_error_assessment/2023-01-04_superconduct_RF_0.00062Bias_50Trials_PVs.csv'
AUC_results_path = calculate_AUC(predictive_values_file_path, dataset, mu)
print("Saved AUC results at path : " + AUC_results_path)


'''
If not 1st run : 
    Comment 3 lines above (used for 1st run)
    Uncomment 1st line below and specify 'AUC_results_path' as output from 'calculate_AUC' function above
    Optionally : Uncomment 2nd line below to delete file located at 'predictive_values_file_path' for storage
'''
# AUC_results_path = ''
### if (os.path.exists(predictive_values_file_path)): os.remove(predictive_values_file_path)


'''Plot AUC results'''
plot_AUC(AUC_results_path, dataset, mu, num_trials)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [11:24<00:00, 13.68s/it]
# Saved AUC results at path : ./results/JAWE_error_assessment/2023-01-04_AUC_superconduct_RF_data.csv

# %% [markdown]
# ### Superconduct NN

# %%
'''Specify dataset and mu function (predictor) here'''

dataset = 'superconduct' ## dataset \in ['airfoil', 'wine', 'wave', 'superconduct', 'communities']
mu = 'NN'  ## mu \in ['RF', 'NN']
num_trials = 50

'''
If 1st run : Specify 'predictive_values_file_path' as output of '20220729_run_JAW_PredictiveValuesForAUC.py'
             for dataset and mu above
'''
predictive_values_file_path = './results/JAWE_error_assessment/2023-01-04_superconduct_NN_0.00062Bias_50Trials_PVs.csv'
AUC_results_path = calculate_AUC(predictive_values_file_path, dataset, mu)
print("Saved AUC results at path : " + AUC_results_path)


'''
If not 1st run : 
    Comment 3 lines above (used for 1st run)
    Uncomment 1st line below and specify 'AUC_results_path' as output from 'calculate_AUC' function above
    Optionally : Uncomment 2nd line below to delete file located at 'predictive_values_file_path' for storage
'''
# AUC_results_path = ''
### if (os.path.exists(predictive_values_file_path)): os.remove(predictive_values_file_path)


'''Plot AUC results'''
plot_AUC(AUC_results_path, dataset, mu, num_trials)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [11:59<00:00, 14.39s/it]
# Saved AUC results at path : ./results/JAWE_error_assessment/2023-01-04_AUC_superconduct_NN_data.csv

# %% [markdown]
# ### Communities RF

# %%
'''Specify dataset and mu function (predictor) here'''

dataset = 'communities' ## dataset \in ['airfoil', 'wine', 'wave', 'superconduct', 'communities']
mu = 'RF'  ## mu \in ['RF', 'NN']
num_trials = 50

'''
If 1st run : Specify 'predictive_values_file_path' as output of '20220729_run_JAW_PredictiveValuesForAUC.py'
             for dataset and mu above
'''
predictive_values_file_path = './results/JAWE_error_assessment/2023-01-04_communities_RF_0.825Bias_50Trials_PVs.csv'
AUC_results_path = calculate_AUC(predictive_values_file_path, dataset, mu)
print("Saved AUC results at path : " + AUC_results_path)


'''
If not 1st run : 
    Comment 3 lines above (used for 1st run)
    Uncomment 1st line below and specify 'AUC_results_path' as output from 'calculate_AUC' function above
    Optionally : Uncomment 2nd line below to delete file located at 'predictive_values_file_path' for storage
'''
# AUC_results_path = ''
### if (os.path.exists(predictive_values_file_path)): os.remove(predictive_values_file_path)


'''Plot AUC results'''
plot_AUC(AUC_results_path, dataset, mu, num_trials)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [10:55<00:00, 13.12s/it]
# Saved AUC results at path : ./results/JAWE_error_assessment/2023-01-04_AUC_communities_RF_data.csv

# %% [markdown]
# ### Communities data NN

# %%
'''Specify dataset and mu function (predictor) here'''

dataset = 'communities' ## dataset \in ['airfoil', 'wine', 'wave', 'superconduct', 'communities']
mu = 'NN'  ## mu \in ['RF', 'NN']
num_trials = 50

'''
If 1st run : Specify 'predictive_values_file_path' as output of '20220729_run_JAW_PredictiveValuesForAUC.py'
             for dataset and mu above
'''
predictive_values_file_path = './results/JAWE_error_assessment/2023-01-04_communities_NN_0.825Bias_50Trials_PVs.csv'
AUC_results_path = calculate_AUC(predictive_values_file_path, dataset, mu)
print("Saved AUC results at path : " + AUC_results_path)


'''
If not 1st run : 
    Comment 3 lines above (used for 1st run)
    Uncomment 1st line below and specify 'AUC_results_path' as output from 'calculate_AUC' function above
    Optionally : Uncomment 2nd line below to delete file located at 'predictive_values_file_path' for storage
'''
# AUC_results_path = ''
### if (os.path.exists(predictive_values_file_path)): os.remove(predictive_values_file_path)


'''Plot AUC results'''
plot_AUC(AUC_results_path, dataset, mu, num_trials)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [11:54<00:00, 14.28s/it]
# Saved AUC results at path : ./results/JAWE_error_assessment/2023-01-04_AUC_communities_NN_data.csv
